# %%
import pandas as pd

# %%
nba_url='https://raw.githubusercontent.com/data602sps/datasetspractice/main/nba.csv'
df1 = pd.read_csv(nba_url)

# %%
df1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# 458 rows and 9 columns

# %%
print(df1.shape)
print(df1.dtypes)
# Out:
# (458, 9)
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
# 5 object types, 4 float64 types

# %%
df1.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# I see there are descriptive stats for just the numerical columns. According to the documentation for describe(), you need to specifiy the `include` parameter to see all of the columns.
#
# I see the weight has the highest spread out of the numerical columns.

# %%
df1.head()

# %% [markdown]
# This shows the first 5 rows in the dataset.

# %%
df1.tail()

# %% [markdown]
# This shows the last 5 rows in the dataset.

# %% [markdown]
# 2nd dataset

# %%
weather_url='https://raw.githubusercontent.com/data602sps/datasetspractice/main/weather.csv'
df2 = pd.read_csv(weather_url)

# %%
df2
# Out:
#       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 0              1    EWR  2013    1.0   1.0   0.0  37.04  21.92  53.97
# 1              2    EWR  2013    1.0   1.0   1.0  37.04  21.92  53.97
# 2              3    EWR  2013    1.0   1.0   2.0  37.94  21.92  52.09
# 3              4    EWR  2013    1.0   1.0   3.0  37.94  23.00  54.51
# 4              5    EWR  2013    1.0   1.0   4.0  37.94  24.08  57.04
# ...          ...    ...   ...    ...   ...   ...    ...    ...    ...
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# 8718        8719    LGA  2013    8.0  22.0  22.0  75.92  66.92  73.68
#
#       wind_dir  wind_speed  wind_gust  precip  pressure  visib
# 0        230.0    10.35702  11.918651     0.0    1013.9   10.0
# ...

# %% [markdown]
# 8719 rows and 15 columns

# %%
print(df2.shape)
print(df2.dtypes)

# %%
df2.describe()
# Out:
#         Unnamed: 0    year        month          day         hour  \
# count  8719.000000  8719.0  8718.000000  8718.000000  8718.000000
# mean   4360.000000  2013.0     6.506538    15.679628    11.515715
# std    2517.102832     0.0     3.439961     8.768250     6.916846
# min       1.000000  2013.0     1.000000     1.000000     0.000000
# 25%    2180.500000  2013.0     4.000000     8.000000     6.000000
# 50%    4360.000000  2013.0     7.000000    16.000000    12.000000
# 75%    6539.500000  2013.0     9.000000    23.000000    18.000000
# max    8719.000000  2013.0    12.000000    31.000000    23.000000
#
#               temp         dewp        humid     wind_dir   wind_speed  \
# count  8718.000000  8718.000000  8718.000000  8486.000000  8718.000000
# mean     55.484942    41.794184    62.863333   193.194674     9.335732
# std      18.345817    19.619776    19.572699   110.541333    12.328261
# min      10.940000    -9.040000    13.950000     0.000000     0.000000
# ...

# %% [markdown]
# I see the `count` differs for some of the columns. For example, year has 8719 values and month has 8718. Maybe this is an indication that there are missing values.

# %%
df2.head()

# %%
df2.tail()

# %% [markdown]
# 3rd dataset

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/djunga/602/main/spotify_artist_data.csv')

# %%
df3
# Out:
#       Unnamed: 0    Artist Name    Lead Streams           Feats Tracks  \
# 0              1          Drake  50,162,292,808  19,246,513,666    262
# 1              2      Bad Bunny  44,369,032,140   5,391,990,975    163
# 2              3     Ed Sheeran  38,153,682,361   2,791,278,201    240
# 3              4     The Weeknd  34,767,779,741   4,288,903,657    186
# 4              5   Taylor Swift  32,596,728,109     424,053,296    323
# ...          ...            ...             ...             ...    ...
# 1004        1005          Gotye   1,424,591,618      10,576,378     46
# 1005        1006           NIKI   1,422,920,850     231,405,433     55
# 1006        1007    Duke Dumont   1,422,096,182      24,622,115    121
# 1007        1008  Laura Pausini   1,421,622,604     293,291,443    434
# 1008        1009           Beck   1,420,597,420      83,871,063    300
#
#      One Billion 100 Million Last Updated
# 0              6         130     19.09.22
# ...

# %% [markdown]
# 1009 rows and 8 columns

# %%
print(df3.shape)
print(df3.dtypes)
# Out:
# (1009, 8)
# Unnamed: 0       int64
# Artist Name     object
# Lead Streams    object
# Feats           object
# Tracks          object
# One Billion     object
# 100 Million     object
# Last Updated    object
# dtype: object

# %% [markdown]
# Besides the Unamed:0 column, each column is of the `object` datatype.

# %%
df3.describe()
# Out:
#         Unnamed: 0
# count  1009.000000
# mean    505.000000
# std     291.417513
# min       1.000000
# 25%     253.000000
# 50%     505.000000
# 75%     757.000000
# max    1009.000000

# %% [markdown]
# There's only 1 column because by default, describe() only acknowledges numerical columns.

# %%
df3.head()
# Out:
#    Unnamed: 0   Artist Name    Lead Streams           Feats Tracks  \
# 0           1         Drake  50,162,292,808  19,246,513,666    262
# 1           2     Bad Bunny  44,369,032,140   5,391,990,975    163
# 2           3    Ed Sheeran  38,153,682,361   2,791,278,201    240
# 3           4    The Weeknd  34,767,779,741   4,288,903,657    186
# 4           5  Taylor Swift  32,596,728,109     424,053,296    323
#
#   One Billion 100 Million Last Updated
# 0           6         130     19.09.22
# 1           5         118     20.09.22
# 2          10          62     19.09.22
# 3           8          72     19.09.22
# 4           1          96     20.09.22

# %% [markdown]
# We can see that there is more than just 1 numerical column, as thought before. We can probably coerce some of these columns to be numerical.

# %%
df3.tail()

# %% [markdown]
# 4th dataset

# %%
df4 = pd.read_csv('https://raw.githubusercontent.com/djunga/602/main/googleplaystore.csv')

# %%
df4
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# 10841 rows, 13 columns

# %%
print(df4.shape)
print(df4.dtypes)
# Out:
# (10841, 13)
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# Mostly `object` columns.

# %%
df4.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# We only see 1 numerical column. Maybe there are others that can be coerced, as in the last dataset.

# %%
df4.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# `Reviews`, and `Price` can probably be coerced.

# %%
df4.tail()
